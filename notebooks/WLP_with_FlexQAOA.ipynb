# %% [markdown]
# # 🏭 Warehouse Location Problem with FlexQAOA
#
# This notebook demonstrates solving a **Warehouse Location Problem** using Aqarios's FlexQAOA algorithm. The Warehouse Location Problem is a classic facility location optimization challenge that determines which warehouses to open and how to assign customers to minimize total cost. 🎯
#
# The problem formulation considers:
# - 🚚 Transportation costs from warehouses to customers
# - 💰 Setup costs for opening new warehouses at given locations
#
# ## 🔍 Overview
#
# 1. **Setup**
# 2. **Definition of Warehouse Location Problem with Luna Model**
# 3. **Solving the optimization problem with Luna**
# 4. **Comparison of FlexQAOA and building blocks**
# 5. **Inspecting in Luna Dashboard**
# 6. **Q&A**
#
# ## 📦 Imports and Setup

# %%
import os
import sys

from luna_quantum import Model, Variable, Vtype, quicksum

sys.path.append(os.path.abspath(".."))  # or path to your project root

import getpass
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

from luna_quantum.solve.parameters.algorithms.base_params import (
    LinearQAOAParams,
    ScipyOptimizerParams,
)
from luna_quantum.solve.parameters.algorithms.quantum_gate.flexqaoa import (
    IndicatorFunctionConfig,
    PipelineParams,
    QuadraticPenaltyConfig,
    XYMixerConfig,
)

from utils.plotting import plot_warehouse_network, solution_to_arrays

if "LUNA_API_KEY" not in os.environ:
    # Prompt securely for the key if not already set
    os.environ["LUNA_API_KEY"] = getpass.getpass("Enter your Luna API key: ")

# %% [markdown]
# ![LunaSolve Flow Algorithm Selection](plots/LunaSolve.png)

# %% [markdown]
# ## 📋 Problem Data Definition
#
# Here we define the key components of our warehouse location problem:

# %% [markdown]
# 🏭 1. Warehouses (Potential Facilities)

# %%
facilities = {
    "Munich": {"cost": 50, "capacity": 7},
    "Nuremberg": {"cost": 40, "capacity": 6},
}

# %% [markdown]
# 🏥 2. Hospitals (Customers/Demand Points)

# %%
hospitals = {
    "H2": {"location": "Munich-North", "demand": 4},
    "H3": {"location": "Nuremberg-South", "demand": 3},
    "H4": {"location": "Augsburg-West", "demand": 2},
    "H8": {"location": "Erlangen", "demand": 1},
}

# %% [markdown]
# 🚛 3. Transportation Costs

# %%
transport_costs = {
    ("H2", "Munich"): 0.15,
    ("H2", "Nuremberg"): 0.40,
    ("H2", "Augsburg"): 0.30,
    ("H2", "Regensburg"): 0.55,
    ("H3", "Munich"): 0.40,
    ("H3", "Nuremberg"): 0.12,
    ("H3", "Augsburg"): 0.50,
    ("H3", "Regensburg"): 0.35,
    ("H4", "Munich"): 0.45,
    ("H4", "Nuremberg"): 0.18,
    ("H4", "Augsburg"): 0.55,
    ("H4", "Regensburg"): 0.40,
    ("H8", "Munich"): 0.40,
    ("H8", "Nuremberg"): 0.15,
    ("H8", "Augsburg"): 0.45,
    ("H8", "Regensburg"): 0.30,
}

# %%
plot_warehouse_network(facilities, hospitals, transport_costs)

# %% [markdown]
# # Modelling the Warehouse Location Problem with AqModels

# %%
depot = "Munich"
m = Model("Warehouse Location Problem")

# add variables
x = {}
y = {}
with m.environment:
    for f in facilities:
        for h in hospitals:
            x[(f, h)] = Variable(vtype=Vtype.BINARY, name=f"x_{f},{h}")
        y[f] = Variable(vtype=Vtype.BINARY, name=f"y_{f}")

# add cost to transport goods
m.objective += quicksum(
    x[f, h] * transport_costs[(h, f)] * hospitals[h]["demand"]
    for f in facilities
    for h in hospitals
)

# add cost to open facility
m.objective += quicksum(y[f] * facilities[f]["cost"] for f in facilities)

# each hospital must be delivered
for h in hospitals:
    m.add_constraint(
        quicksum(x[f, h] for f in facilities) == 1, name=f"deliver_hospital_{h}"
    )

# at most usage of capacity
for f in facilities:
    m.add_constraint(
        quicksum(hospitals[h]["demand"] * x[f, h] for h in hospitals)
        <= facilities[f]["capacity"] * y[f],
        name=f"deliver_{f}",
    )

print(m)
# Out:
# Model: Warehouse Location Problem
# Minimize
#   0.6 * x_Munich,H2 + 1.2000000000000002 * x_Munich,H3 + 0.9 * x_Munich,H4
#   + 0.4 * x_Munich,H8 + 50 * y_Munich + 1.6 * x_Nuremberg,H2
#   + 0.36 * x_Nuremberg,H3 + 0.36 * x_Nuremberg,H4 + 0.15 * x_Nuremberg,H8
#   + 40 * y_Nuremberg
# Subject To
#   deliver_hospital_H2: x_Munich,H2 + x_Nuremberg,H2 == 1
#   deliver_hospital_H3: x_Munich,H3 + x_Nuremberg,H3 == 1
#   deliver_hospital_H4: x_Munich,H4 + x_Nuremberg,H4 == 1
#   deliver_hospital_H8: x_Munich,H8 + x_Nuremberg,H8 == 1
#   deliver_Munich: 4 * x_Munich,H2 + 3 * x_Munich,H3 + 2 * x_Munich,H4
#     + x_Munich,H8 - 7 * y_Munich <= 0
#   deliver_Nuremberg: 4 * x_Nuremberg,H2 + 3 * x_Nuremberg,H3
#     + 2 * x_Nuremberg,H4 + x_Nuremberg,H8 - 6 * y_Nuremberg <= 0
# Binary
#   x_Munich,H2 x_Munich,H3 x_Munich,H4 x_Munich,H8 y_Munich x_Nuremberg,H2
#   x_Nuremberg,H3 x_Nuremberg,H4 x_Nuremberg,H8 y_Nuremberg

# %% [markdown]
# # Solving the Warehouse Location Problem with LunaSolve

# %%
from luna_quantum.algorithms import FlexQAOA

alg = FlexQAOA()
job = alg.run(model=m, name="WLP with FlexQAOA")

# %%
solution = job.result()
print(solution)
# Out:
# Waiting for result | elapsed 0:00:01 | poll 1 | next check in 0.5s
# Waiting for result | elapsed 0:00:02 | poll 2 | next check in 1s
# 2026-08-05 15:52:25 INFO     Solve job '29642579-d2a1-4855-a24a-2381a70a2cb3' finished with status 'DONE' after
#                              0:00:03.
# x_Nur x_Mun x_Nur x_Nur y_Nur x_Mun x_Mun x_Mun     │ feas   raw   obj count
#     1     1     1     0     1     0     0     0 ... │    t 91.47 91.47    85
#     1     1     1     0     1     0     0     1 ... │    t 91.72 91.72    47
#     0     1     1     0     1     0     1     0 ... │    t 92.01 92.01    47
#     0     1     1     0     1     0     1     1 ... │    t 92.26 92.26    54
#     1     1     0     0     1     1     0     0 ... │    t 92.31 92.31    40
#     1     0     0     1     1     1     0     1 ... │    t 93.56 93.56    49
#     0     0     0     1     1     1     1     0 ... │    t 93.85 93.85    52
#     0     0     0     1     1     1     1     1 ... │    t  94.1  94.1    70
#     1     1     1     0     0     0     0     1 ... │    f 361.7  1.72     4
#     0     1     1     0     0     0     1     0 ... │    f 362.0  2.01     4
# ...
#
# Total samples: 1024
# Unique samples: 55
# Total variables: 10
#
# Timing:
# Total: 0.167065621s

# %%
## post optimization pipeline
best_solution = solution.best()[0]

# %% [markdown]
# # 🔄 Model Transformation Pipeline (Upcoming Feature)

# %%
from luna_model.transformation import PassManager
from luna_model.transformation.pipelines import ToUnconstrainedBinaryPipeline

pass_manager = PassManager(passes=[ToUnconstrainedBinaryPipeline()])
ir = pass_manager.run(m)
print(ir.model)
# Out:
# Model: Warehouse Location Problem
# Minimize
#   12000 * x_Munich,H2 * x_Munich,H3 + 8000 * x_Munich,H2 * x_Munich,H4
#   + 4000 * x_Munich,H2 * x_Munich,H8 - 28000 * x_Munich,H2 * y_Munich
#   + 1000 * x_Munich,H2 * x_Nuremberg,H2
#   - 4000 * x_Munich,H2 * slack_deliver_Munich_b0
#   - 8000 * x_Munich,H2 * slack_deliver_Munich_b1
#   - 16000 * x_Munich,H2 * slack_deliver_Munich_b2
#   + 6000 * x_Munich,H3 * x_Munich,H4 + 3000 * x_Munich,H3 * x_Munich,H8
#   - 21000 * x_Munich,H3 * y_Munich + 1000 * x_Munich,H3 * x_Nuremberg,H3
#   - 3000 * x_Munich,H3 * slack_deliver_Munich_b0
#   - 6000 * x_Munich,H3 * slack_deliver_Munich_b1
#   - 12000 * x_Munich,H3 * slack_deliver_Munich_b2
#   + 2000 * x_Munich,H4 * x_Munich,H8 - 14000 * x_Munich,H4 * y_Munich
#   + 1000 * x_Munich,H4 * x_Nuremberg,H4
#   - 2000 * x_Munich,H4 * slack_deliver_Munich_b0
#   - 4000 * x_Munich,H4 * slack_deliver_Munich_b1
#   - 8000 * x_Munich,H4 * slack_deliver_Munich_b2 - 7000 * x_Munich,H8 * y_Munich
#   + 1000 * x_Munich,H8 * x_Nuremberg,H8
#   - 1000 * x_Munich,H8 * slack_deliver_Munich_b0
#   - 2000 * x_Munich,H8 * slack_deliver_Munich_b1
#   - 4000 * x_Munich,H8 * slack_deliver_Munich_b2
#   + 7000 * y_Munich * slack_deliver_Munich_b0
#   + 14000 * y_Munich * slack_deliver_Munich_b1
#   + 28000 * y_Munich * slack_deliver_Munich_b2
#   + 12000 * x_Nuremberg,H2 * x_Nuremberg,H3
#   + 8000 * x_Nuremberg,H2 * x_Nuremberg,H4
#   + 4000 * x_Nuremberg,H2 * x_Nuremberg,H8
#   - 24000 * x_Nuremberg,H2 * y_Nuremberg
#   - 4000 * x_Nuremberg,H2 * slack_deliver_Nuremberg_b0
#   - 8000 * x_Nuremberg,H2 * slack_deliver_Nuremberg_b1
#   - 12000 * x_Nuremberg,H2 * slack_deliver_Nuremberg_b2
#   + 6000 * x_Nuremberg,H3 * x_Nuremberg,H4
#   + 3000 * x_Nuremberg,H3 * x_Nuremberg,H8
#   - 18000 * x_Nuremberg,H3 * y_Nuremberg
#   - 3000 * x_Nuremberg,H3 * slack_deliver_Nuremberg_b0
#   - 6000 * x_Nuremberg,H3 * slack_deliver_Nuremberg_b1
#   - 9000 * x_Nuremberg,H3 * slack_deliver_Nuremberg_b2
#   + 2000 * x_Nuremberg,H4 * x_Nuremberg,H8
#   - 12000 * x_Nuremberg,H4 * y_Nuremberg
#   - 2000 * x_Nuremberg,H4 * slack_deliver_Nuremberg_b0
#   - 4000 * x_Nuremberg,H4 * slack_deliver_Nuremberg_b1
#   - 6000 * x_Nuremberg,H4 * slack_deliver_Nuremberg_b2
#   - 6000 * x_Nuremberg,H8 * y_Nuremberg
#   - 1000 * x_Nuremberg,H8 * slack_deliver_Nuremberg_b0
#   - 2000 * x_Nuremberg,H8 * slack_deliver_Nuremberg_b1
#   - 3000 * x_Nuremberg,H8 * slack_deliver_Nuremberg_b2
#   + 6000 * y_Nuremberg * slack_deliver_Nuremberg_b0
#   + 12000 * y_Nuremberg * slack_deliver_Nuremberg_b1
#   + 18000 * y_Nuremberg * slack_deliver_Nuremberg_b2
#   + 2000 * slack_deliver_Munich_b0 * slack_deliver_Munich_b1
#   + 4000 * slack_deliver_Munich_b0 * slack_deliver_Munich_b2
#   + 8000 * slack_deliver_Munich_b1 * slack_deliver_Munich_b2
#   + 2000 * slack_deliver_Nuremberg_b0 * slack_deliver_Nuremberg_b1
#   + 3000 * slack_deliver_Nuremberg_b0 * slack_deliver_Nuremberg_b2
#   + 6000 * slack_deliver_Nuremberg_b1 * slack_deliver_Nuremberg_b2
#   + 35500.6 * x_Munich,H2 + 25001.2 * x_Munich,H3 + 15500.9 * x_Munich,H4
#   + 7000.4 * x_Munich,H8 - 24450 * y_Munich + 31501.6 * x_Nuremberg,H2
#   + 22000.36 * x_Nuremberg,H3 + 13500.36 * x_Nuremberg,H4
#   + 6000.15 * x_Nuremberg,H8 - 17960 * y_Nuremberg
#   - 6500 * slack_deliver_Munich_b0 - 12000 * slack_deliver_Munich_b1
#   - 20000 * slack_deliver_Munich_b2 - 5500 * slack_deliver_Nuremberg_b0
#   - 10000 * slack_deliver_Nuremberg_b1 - 13500 * slack_deliver_Nuremberg_b2
#   + 44500
# Binary
#   x_Munich,H2 x_Munich,H3 x_Munich,H4 x_Munich,H8 y_Munich x_Nuremberg,H2
#   x_Nuremberg,H3 x_Nuremberg,H4 x_Nuremberg,H8 y_Nuremberg
#   slack_deliver_Munich_b0 slack_deliver_Munich_b1 slack_deliver_Munich_b2
#   slack_deliver_Nuremberg_b0 slack_deliver_Nuremberg_b1
#   slack_deliver_Nuremberg_b2

# %%
from luna_quantum import algorithms

alg = algorithms.SimulatedAnnealing(num_reads=100)
job = alg.run(model=ir.model, name="WLP with PA")

# %%
sol = job.result()
sol = ir.record.backward(sol)
print(sol)
# Out:
# Waiting for result | elapsed 0:00:00 | poll 1 | next check in 0.5s
# Waiting for result | elapsed 0:00:01 | poll 2 | next check in 1s
# 2026-08-05 15:52:30 INFO     Solve job 'c1f76953-8550-472a-acc9-07bf7cea400b' finished with status 'DONE' after
#                              0:00:03.
# x_Nur x_Mun x_Mun x_Nur x_Mun y_Nur x_Nur y_Mun x_Nur     │ feas   raw obj count
#     1     0     1     1     0     1     1     1     0 ... │    t 91.47   ?     3
#     1     0     1     0     0     1     1     1     0 ... │    t 91.72   ?     3
#     1     1     1     1     0     1     0     1     0 ... │    t 92.01   ?     4
#     1     1     1     0     0     1     0     1     0 ... │    t 92.26   ?     8
#     0     0     1     1     1     1     1     1     0 ... │    t 92.31   ?    11
#     0     0     0     0     1     1     1     1     1 ... │    t 93.56   ?     4
#     0     1     0     1     1     1     0     1     1 ... │    t 93.85   ?     3
#     0     1     0     0     1     1     0     1     1 ... │    t  94.1   ?     6
#     1     0     0     1     0     1     1     0     0 ... │    t 540.9   ?     3
#     0     1     1     0     0     0     0     1     0 ... │    t 551.9   ?     3
# ...
#
# Total samples: 100
# Unique samples: 40
# Total variables: 10
#
# Timing:
# Total: 0.031649589s

# %% [markdown]
# # 🔬 Indepth comparison of different FlexQAOA configurations
# We will compare different FlexQAOA configurations with the same base configuration.

# %%
shared_config = {
    "reps": 4,
    "initial_params": LinearQAOAParams(delta_beta=0.2, delta_gamma=0.2),
    "optimizer": ScipyOptimizerParams(method="BFGS"),
}

# %% [markdown]
# 📊 Standard QAOA: A FlexQAOA pipeline without advanced constraint handling (effectively the default QAOA algorithm)

# %%
qaoa = algorithms.FlexQAOA(
    **shared_config,
    pipeline=PipelineParams(
        indicator_function=IndicatorFunctionConfig(enable=False),
        xy_mixer=XYMixerConfig(enable=False),
        quadratic_penalty=QuadraticPenaltyConfig(enable=True),
    ),
)

# %% [markdown]
# 🔢 One-Hot Encoding FlexQAOA: A FlexQAOA with a one-hot encoding of the binary variables

# %%
oh_qaoa = algorithms.FlexQAOA(
    **shared_config,
    pipeline=PipelineParams(
        indicator_function=IndicatorFunctionConfig(enable=False),
        xy_mixer=XYMixerConfig(enable=True),
        quadratic_penalty=QuadraticPenaltyConfig(enable=True),
    ),
)

# %% [markdown]
# 🚩 Indicator Function FlexQAOA: A FlexQAOA with an indicator function for the binary variables

# %%
if_qaoa = algorithms.FlexQAOA(
    **shared_config,
    pipeline=PipelineParams(
        indicator_function=IndicatorFunctionConfig(enable=True),
        xy_mixer=XYMixerConfig(enable=False),
        quadratic_penalty=QuadraticPenaltyConfig(enable=True),
    ),
)

# %% [markdown]
# 🎯 Full FlexQAOA: A FlexQAOA pipeline with full functionality enabled

# %%
flex_qaoa = algorithms.FlexQAOA(**shared_config)

# %%
oh_job = oh_qaoa.run(model=m, name="QAOA with Onehots")
if_job = if_qaoa.run(model=m, name="QAOA with Indicators Function")
flex_job = flex_qaoa.run(model=m, name="QAOA with FlexQAOA")
qaoa_job = qaoa.run(model=m, name="QAOA Default")

# %% [markdown]
# ## ⚡ FlexQAOA Algorithm Configuration
#
# **FlexQAOA** (Flexible Quantum Approximate Optimization Algorithm) is a quantum optimization algorithm that can handle constrained optimization problems efficiently! 🔧
#
# ### 🛠️ Algorithm Parameters:
# - **reps**: Number of QAOA layers (depth of the quantum circuit) 🔄
# - **initial_params**: Starting parameters for the optimization 🎯
# - **optimizer**: Classical optimizer used to update QAOA parameters 🚀

# %%
qaoa_sol = qaoa_job.result()
ohc_sol = oh_job.result()
if_sol = if_job.result()
flex_sol = flex_job.result()
# Out:
# Waiting for result | elapsed 0:00:00 | poll 1 | next check in 0.5s
# Waiting for result | elapsed 0:00:01 | poll 2 | next check in 1s
# Waiting for result | elapsed 0:00:03 | poll 3 | next check in 2s
# Waiting for result | elapsed 0:00:05 | poll 4 | next check in 4s
# Waiting for result | elapsed 0:00:09 | poll 5 | next check in 8s
# Waiting for result | elapsed 0:00:18 | poll 6 | next check in 16s
# 2026-08-05 15:53:13 INFO     Solve job '762a8338-d864-4697-9790-0b5cd57548b7' finished with status 'DONE' after
#                              0:00:34.
# 2026-08-05 15:53:14 INFO     Solve job 'ef69122f-ed7a-4a5c-a143-5fe112d8d44e' finished with status 'DONE' after
#                              0:00:00.
# 2026-08-05 15:53:15 INFO     Solve job '55fd20f7-3756-45a8-9100-b885992ddcc4' finished with status 'DONE' after
#                              0:00:00.
# 2026-08-05 15:53:16 INFO     Solve job '7b854f2d-46ba-4418-be40-bcfad0b47ab9' finished with status 'DONE' after
#                              0:00:00.

# %% [markdown]
# ## 📥 Solution Retrieval
#
# The algorithm runs asynchronously on quantum hardware or simulators. The `job.result()` method retrieves the solution once the optimization is complete. ⏳

# %%
import matplotlib.pyplot as plt

flex_obj, flex_count = solution_to_arrays(flex_sol)
ohc_obj, ohc_count = solution_to_arrays(ohc_sol)
if_obj, if_count = solution_to_arrays(if_sol)
qaoa_obj, qaoa_count = solution_to_arrays(qaoa_sol)
plt.figure(figsize=(12, 6))
plt.step(
    qaoa_obj, qaoa_count, label="Objective Function QAOA", color="#013CF2", linewidth=3
)
plt.step(
    flex_obj,
    flex_count,
    label="Objective Function FlexQAOA",
    color="#EBC25B",
    linewidth=3,
)
plt.step(
    ohc_obj,
    ohc_count,
    label="Objective Function XY-Mixer QAOA",
    color="#538A6A",
    linewidth=3,
)
plt.step(
    if_obj,
    if_count,
    label="Objective Function Indicator QAOA",
    color="#7F7F7F",
    linewidth=3,
)

# Add labels and title
plt.xlabel("Objective Value")
plt.ylabel("Percentage of Samples")
plt.title("Feasible solution")
plt.ylim(0, 1)

plt.grid(False)
plt.axvline(
    x=91.47, color="black", linestyle="--", linewidth=2, label="Optimal Solution"
)

# Position legend to the right outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")

# Adjust layout to prevent legend cutoff
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ![LunaSolve Flow Algorithm Selection](plots/LunaDashboard.png)

# %% [markdown]
# ## 🎉 Conclusion
#
# This notebook demonstrated how to solve a **Warehouse Location Problem** using Luna Quantum's FlexQAOA algorithm! 🚀
#
# ### 🔑 Key Takeaways:
#
# 1. **Problem Modeling**: Easily model with Luna Model library, load existing models with translators or use our predefined use cases
# 2. **Quantum and Classical Algorithms**: Easily switch between algorithms by leveraging our intuitive interface and transformations
# 3. **Solution Quality**: FlexQAOA applies the most efficient optimization pipeline to find better solutions faster
#
# **Happy optimizing!** 🎯✨

# %% [markdown]
# ![LunaSolve Flow Algorithm Selection](plots/ApplicationsAreas.png)
